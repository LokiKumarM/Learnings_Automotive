# %%
import os
from dotenv import load_dotenv

load_dotenv()
from langchain_groq import ChatGroq

# %%
def llm_call(prompt: str, system_prompt: str = "", model="llama3-70b-8192") -> str:
    """
    Calls the model with the given prompt and returns the response.

    Args:
        prompt (str): The user prompt to send to the model.
        system_prompt (str, optional): The system prompt to send to the model. Defaults to "".
        model (str, optional): The model to use for the call. Defaults to "llama3-70b-8192".

    Returns:
        str: The response from the language model.
    """
    
    messages = [{"role": "user", "content": prompt}]
    
    llm = ChatGroq(
    model=model,
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY")
    )

    response = llm.invoke(messages)
    return response.content.strip()

# %%
import re

def extract_xml(text: str, tag: str) -> str:
    """
    Extracts the content of the specified XML tag from the given text. Used for parsing structured responses 

    Args:
        text (str): The text containing the XML.
        tag (str): The XML tag to extract content from.

    Returns:
        str: The content of the specified XML tag, or an empty string if the tag is not found.
    """
    match = re.search(f'<{tag}>(.*?)</{tag}>', text, re.DOTALL)
    return match.group(1) if match else ""

# %%
from typing import Dict, List, Optional

#converting XML content into dictionary value
def parse_tasks(tasks_xml: str) -> List[Dict]:
    """Parse XML tasks into a list of task dictionaries."""
    tasks = []
    current_task = {}
    
    for line in tasks_xml.split('\n'):
        line = line.strip()
        if not line:
            continue
            
        if line.startswith("<task>"):
            current_task = {}
        elif line.startswith("<type>"):
            current_task["type"] = line[6:-7].strip()
        elif line.startswith("<description>"):
            current_task["description"] = line[12:-13].strip()
        elif line.startswith("</task>"):
            if "description" in current_task:
                if "type" not in current_task:
                    current_task["type"] = "default"
                tasks.append(current_task)
    
    return tasks

class FlexibleOrchestrator:
    """Break down tasks and run them in parallel using worker LLMs."""
    
    def __init__(
        self,
        orchestrator_prompt: str,
        worker_prompt: str,
    ):
        """Initialize with prompt templates."""
        self.orchestrator_prompt = orchestrator_prompt
        self.worker_prompt = worker_prompt
    
    # formating prompt by replacing {} variables with its actual value 
    def _format_prompt(self, template: str, **kwargs) -> str:
        """Format a prompt template with variables."""
        try:
            return template.format(**kwargs)
        except KeyError as e:
            raise ValueError(f"Missing required prompt variable: {e}")

    def process(self, task: str, context: Optional[Dict] = None) -> Dict:
        """Process task by breaking it down and running subtasks in parallel."""
        context = context or {}
        
        # Step 1: Get orchestrator response
        orchestrator_input = self._format_prompt(
            self.orchestrator_prompt,
            task=task,
            **context
        )
        orchestrator_response = llm_call(orchestrator_input)
        
        # Parse orchestrator response
        analysis = extract_xml(orchestrator_response, "analysis")
        tasks_xml = extract_xml(orchestrator_response, "tasks")
        tasks = parse_tasks(tasks_xml)
        
        print("\n=== ORCHESTRATOR OUTPUT ===")
        print(f"\nANALYSIS:\n{analysis}")
        print(f"\nTASKS:\n{tasks}")
        
        # Step 2: Process each task
        worker_results = []
        for task_info in tasks:
            worker_input = self._format_prompt(
                self.worker_prompt,
                original_task=task,
                task_type=task_info['type'],
                task_description=task_info['description'],
                **context
            )
            
            worker_response = llm_call(worker_input)
            result = extract_xml(worker_response, "response")
            
            worker_results.append({
                "type": task_info["type"],
                "description": task_info["description"],
                "result": result
            })
            
            print(f"\n=== WORKER RESULT ({task_info['type']}) ===\n{result}\n")
        
        return {
            "analysis": analysis,
            "worker_results": worker_results,
        }

# %%
ORCHESTRATOR_PROMPT = """
Analyze this task and break it down into 2-3 distinct approaches:

Task: {task}

Return your response in this format:

<analysis>
Explain your understanding of the task and which variations would be valuable.
Focus on how each approach serves different aspects of the task.
</analysis>

<tasks>
    <task>
    <type>formal</type>
    <description>Write a precise, technical version that emphasizes specifications</description>
    </task>
    <task>
    <type>conversational</type>
    <description>Write an engaging, friendly version that connects with readers</description>
    </task>
</tasks>
"""

WORKER_PROMPT = """
Generate content based on:
Task: {original_task}
Style: {task_type}
Guidelines: {task_description}

Return your response in this format:

<response>
Your content here, maintaining the specified style and fully addressing requirements.
</response>
"""


orchestrator = FlexibleOrchestrator(
    orchestrator_prompt=ORCHESTRATOR_PROMPT,
    worker_prompt=WORKER_PROMPT,
)

results = orchestrator.process(
    task="Write a product description for a new eco-friendly water bottle",
    context={
        "target_audience": "environmentally conscious millennials",
        "key_features": ["plastic-free", "insulated", "lifetime warranty"],
        "Revenue Model":"Direct from Customers"
    }
)
# Out:
# === ORCHESTRATOR OUTPUT ===
#
# ANALYSIS:
#
# The task of writing a product description for a new eco-friendly water bottle requires a clear understanding of the target audience, the product's features, and the brand's tone. A good product description should effectively communicate the benefits and value of the product to potential customers. There are different approaches to writing a product description, each serving a distinct purpose.
#
# A formal, technical approach would be valuable for customers who prioritize specifications and details, while a conversational, friendly approach would be more suitable for customers who respond to emotional connections and storytelling.
#
# By breaking down the task into distinct approaches, we can cater to different customer personas and preferences, ultimately increasing the product's appeal and chances of conversion.
#
#
# TASKS:
# [{'type': 'technical', 'description': '>Write a precise, technical version that emphasizes specifications, materials, and features, such as BPA-free, insulation, and capacity, to appeal to customers who prioritize functionality and performance.<'}, {'type': 'conversational', 'description': ">Write an engaging, friendly version that connects with readers on an emotional level, highlighting the eco-friendly aspects, the brand's mission, and the benefits of using the product, such as reducing plastic waste and staying hydrated on-the-go.<"}, {'type': 'benefit-focused', 'description': '>Write a version that strikes a balance between technical details and emotional connections, focusing on the benefits of the product, such as how it can help reduce carbon footprint, improve health, and fit into a busy lifestyle.<'}]
#
# === WORKER RESULT (technical) ===
#
#
# Introducing the HydraFlow EcoPro, a cutting-edge water bottle designed to quench your thirst for a sustainable future. Engineered with precision and built with eco-friendly materials, this bottle combines exceptional performance with environmentally responsible design.
#
# **Materials:**
# The HydraFlow EcoPro features a BPA-free Tritan copolyester construction, ensuring a safe and non-toxic drinking experience. The bottle's durable and shatter-resistant design withstands extreme temperatures and rigorous use.
#
# **Insulation:**
# Our proprietary ThermalShield technology provides superior temperature retention, keeping drinks hot for up to 12 hours and cold for up to 24 hours. The double-walled insulation system minimizes heat transfer, ensuring your beverage remains at the perfect temperature.
#
# **Capacity:**
# The HydraFlow EcoPro boasts a generous 27 oz (800ml) capacity, perfect for daily hydration on-the-go. The bottle's slender design fits comfortably in most cup holders and backpack pockets, making it an ideal companion for outdoor enthusiasts, commuters, and fitness enthusiasts alike.
#
# **Features:**
#
# * Leak-proof lid with secure screw-on design
# * Soft-touch, ergonomic grip for comfortable carrying
# * Measurement markings for precise hydration tracking
# * Wide mouth for easy sipping and cleaning
# * Dishwasher safe for convenient maintenance
#
# **Eco-Friendly Credentials:**
#
# * Made from 50% post-consumer recycled materials
# * 100% recyclable at end-of-life
# * Reduces single-use plastic waste and supports a sustainable lifestyle
#
# **Specifications:**
#
# * Dimensions: 10.5" H x 3.5" W x 3.5" D (26.7 cm x 8.9 cm x 8.9 cm)
# * Weight: 10.2 oz (288g)
# * Material thickness: 1.2 mm
# * Operating temperature: -20°C to 100°C (-4°F to 212°F)
#
# Experience the perfect blend of performance, sustainability, and style with the HydraFlow EcoPro. Upgrade your hydration routine with a bottle that not only quenches your thirst but also supports a healthier planet.
#
#
#
#
# === WORKER RESULT (conversational) ===
#
#
# Hey there, fellow earth-lovers!
#
# Are you tired of sipping on single-use plastic water bottles that end up in our oceans and landfills? We sure are! That's why we're stoked to introduce our brand new, eco-friendly water bottle that's about to change the game!
#
# At [Brand Name], we're on a mission to make a difference, one refill at a time. Our bottle is designed to not only quench your thirst but also reduce your carbon footprint. Made from sustainable, BPA-free materials, our bottle is built to last, and we mean it. It's durable, dishwasher safe, and designed for the modern adventurer on-the-go.
#
# But here's the best part: by choosing our eco-friendly water bottle, you're helping to reduce the staggering 8 million tons of plastic waste that ends up in our oceans every year. It's a small change that can make a BIG impact!
#
# Our bottle is designed with you in mind. It's lightweight, easy to carry, and fits perfectly in your bag or backpack. Plus, the double-walled insulation keeps your drinks hot or cold for hours, so you can stay hydrated and focused throughout your busy day.
#
# By joining the [Brand Name] community, you're not just buying a water bottle – you're becoming part of a movement. A movement that cares about the planet, and wants to make a difference. We're committed to donating a portion of our profits to support environmental initiatives, so you can feel good about your purchase.
#
# So, what are you waiting for? Ditch the single-use plastics and upgrade to our eco-friendly water bottle today! Your planet (and your taste buds) will thank you.
#
# Cheers to staying hydrated, and to a greener tomorrow!
#
#
#
#
# === WORKER RESULT (benefit-focused) ===
#
#
# Introducing HydraFlow - the ultimate eco-friendly water bottle that not only quenches your thirst but also nourishes the planet. Made from 100% BPA-free, recyclable materials, HydraFlow is designed to reduce your carbon footprint and promote a healthier you.
#
# Stay hydrated on-the-go with HydraFlow's innovative insulation technology that keeps drinks hot or cold for hours. Whether you're a busy bee or an adventure-seeker, our bottle fits seamlessly into your active lifestyle. The sleek design and comfortable grip make it easy to carry, while the wide mouth opening allows for effortless sipping and cleaning.
#
# But what really sets HydraFlow apart is its commitment to sustainability. By choosing our eco-friendly water bottle, you're reducing your reliance on single-use plastics and helping to minimize the staggering 8 million tons of plastic waste that enter our oceans every year. Plus, our bottle is designed to last, with a durable construction that withstands even the toughest daily use.
#
# HydraFlow is more than just a water bottle - it's a symbol of your commitment to a healthier, more sustainable future. By making the switch to HydraFlow, you're not only improving your own well-being but also contributing to a cleaner, greener planet for generations to come.
#
# Join the movement towards a more eco-conscious lifestyle with HydraFlow. Order now and take the first step towards a healthier, more sustainable you.
