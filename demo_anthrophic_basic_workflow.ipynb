# %%
import os
from dotenv import load_dotenv

load_dotenv()
from langchain_groq import ChatGroq

# %%
def llm_call(prompt: str, system_prompt: str = "", model="llama3-70b-8192") -> str:
    """
    Calls the model with the given prompt and returns the response.

    Args:
        prompt (str): The user prompt to send to the model.
        system_prompt (str, optional): The system prompt to send to the model. Defaults to "".
        model (str, optional): The model to use for the call. Defaults to "llama3-70b-8192".

    Returns:
        str: The response from the language model.
    """
    # client = Anthropic(api_key=os.environ["ANTHROPIC_API_KEY"])
    
    messages = [{"role": "user", "content": prompt}]
    
    # response = client.messages.create(
    #     model=model,
    #     max_tokens=4096,
    #     system=system_prompt,
    #     messages=messages,
    #     temperature=0.1,
    # )
    llm = ChatGroq(
    model=model,
    temperature=0,
    groq_api_key=os.getenv("GROQ_API_KEY")
    )

    response = llm.invoke(messages)
    return response.content.strip()

# %%
from typing import List, Dict, Callable

def chain(input: str, prompts: List[str]) -> str:
    """Chain multiple LLM calls sequentially, passing results between steps."""
    result = input
    for i, prompt in enumerate(prompts, 1):
        print(f"\nStep {i}:")
        #result = llm_call(prompt, result)
        result = llm_call(f"{prompt}\nInput: {result}")
        print(result)
    return result

# %%
# Example 1: Chain workflow for structured data extraction and formatting
# Each step progressively transforms raw text into a formatted table

data_processing_steps = [
    """Extract only the numerical values and their associated metrics from the text.
    Format each as 'value: metric' on a new line.
    Example format:
    92: customer satisfaction
    45%: revenue growth""",
    
    """Convert all numerical values to percentages where possible.
    If not a percentage or points, convert to decimal (e.g., 92 points -> 92%).
    Keep one number per line.
    Example format:
    92%: customer satisfaction
    45%: revenue growth""",
    
    """Sort all lines in descending order by numerical value.
    Keep the format 'value: metric' on each line.
    Example:
    92%: customer satisfaction
    87%: employee satisfaction""",
    
    """Format the sorted data as a markdown table with columns:
    | Metric | Value |
    |:--|--:|
    | Customer Satisfaction | 92% |"""
]

report = """
Q3 Performance Summary:
Our customer satisfaction score rose to 92 points this quarter.
Revenue grew by 45% compared to last year.
Market share is now at 23% in our primary market.
Customer churn decreased to 5% from 8%.
New user acquisition cost is $43 per user.
Product adoption rate increased to 78%.
Employee satisfaction is at 87 points.
Operating margin improved to 34%.
"""

print("\nInput text:")
print(report)
formatted_result = chain(report, data_processing_steps)
print(formatted_result)
# Out:
# Input text:
#
# Q3 Performance Summary:
# Our customer satisfaction score rose to 92 points this quarter.
# Revenue grew by 45% compared to last year.
# Market share is now at 23% in our primary market.
# Customer churn decreased to 5% from 8%.
# New user acquisition cost is $43 per user.
# Product adoption rate increased to 78%.
# Employee satisfaction is at 87 points.
# Operating margin improved to 34%.
#
#
# Step 1:
# Here are the extracted numerical values and their associated metrics:
#
# 92: customer satisfaction score
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost
# 78%: product adoption rate
# 87: employee satisfaction
# 34%: operating margin
#
# Step 2:
# Here is the converted list:
#
# 92%: customer satisfaction score
# 45%: revenue growth
# 23%: market share
# 5%: customer churn
# 43: new user acquisition cost (cannot be converted to percentage)
# 78%: product adoption rate
# 87%: employee satisfaction
# 34%: operating margin
#
# Step 3:
# Here is the sorted list in descending order by numerical value:
#
# 92%: customer satisfaction score
# 87%: employee satisfaction
# 78%: product adoption rate
# 45%: revenue growth
# 43: new user acquisition cost (cannot be converted to percentage)
# 34%: operating margin
# 23%: market share
# 5%: customer churn
#
# Step 4:
# Here is the formatted markdown table:
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |
# | New User Acquisition Cost | 43 |
#
# Let me know if you need any further assistance!
# Here is the formatted markdown table:
#
# | Metric | Value |
# |:--|--:|
# | Customer Satisfaction | 92% |
# | Employee Satisfaction | 87% |
# | Product Adoption Rate | 78% |
# | Revenue Growth | 45% |
# | Operating Margin | 34% |
# | Market Share | 23% |
# | Customer Churn | 5% |
# | New User Acquisition Cost | 43 |
#
# Let me know if you need any further assistance!

# %%
from concurrent.futures import ThreadPoolExecutor

def parallel(prompt: str, inputs: List[str], n_workers: int = 4) -> List[str]:
    """Process multiple inputs concurrently with the same prompt."""
    with ThreadPoolExecutor(max_workers=n_workers) as executor:
        futures = [executor.submit(llm_call, f"{prompt}\nInput: {x}") for x in inputs]
        return [f.result() for f in futures]

# %%
# Example 2: Parallelization workflow for stakeholder impact analysis
# Process impact analysis for multiple stakeholder groups concurrently

stakeholders = [
    """Customers:
    - Price sensitive
    - Want better tech
    - Environmental concerns""",
    
    """Employees:
    - Job security worries
    - Need new skills
    - Want clear direction""",
    
    """Investors:
    - Expect growth
    - Want cost control
    - Risk concerns""",
    
    """Suppliers:
    - Capacity constraints
    - Price pressures
    - Tech transitions"""
]

impact_results = parallel(
    """Analyze how market changes will impact this stakeholder group.
    Provide specific impacts and recommended actions.
    Format with clear sections and priorities.""",
    stakeholders
)

for result in impact_results:
    print(result)
# Out:
# **Market Change Impact Analysis: Customers**
#
# **Section 1: Market Changes**
#
# * **Increasing competition**: New entrants and established players are investing in technology and sustainability, increasing competition in the market.
# * **Shifting consumer preferences**: Consumers are becoming more environmentally conscious and demanding of sustainable practices from companies.
# * **Advancements in technology**: Rapid advancements in technology are driving customer expectations for innovative and efficient products and services.
#
# **Section 2: Impacts on Customers**
#
# **Priority 1: Price Sensitivity**
#
# * **Impact**: Increasing competition may lead to price wars, making it challenging for companies to maintain profit margins while keeping prices low.
# * **Recommended Action**: Implement cost-saving measures without compromising product quality, and explore alternative pricing strategies, such as subscription-based models or value-added services.
#
# **Priority 2: Demand for Better Technology**
#
# * **Impact**: Customers will expect companies to invest in research and development to stay ahead of the technology curve, providing innovative and efficient products and services.
# * **Recommended Action**: Allocate a significant portion of the budget to R&D, focusing on emerging technologies and partnerships with tech startups to stay competitive.
#
# **Priority 3: Environmental Concerns**
#
# * **Impact**: Customers will increasingly expect companies to adopt sustainable practices, reduce carbon footprint, and promote eco-friendly products.
# * **Recommended Action**: Develop and implement a comprehensive sustainability strategy, including supply chain optimization, product redesign, and transparent reporting on environmental impact.
#
# **Section 3: Additional Recommendations**
#
# * **Invest in customer education**: Educate customers on the value of sustainable practices and the benefits of innovative technologies to increase adoption and loyalty.
# * **Enhance customer experience**: Focus on providing a seamless and personalized customer experience across all touchpoints to build brand loyalty and retention.
# * **Monitor and adapt**: Continuously monitor market changes and customer preferences, and be prepared to adapt quickly to stay ahead of the competition.
#
# By prioritizing these recommendations, companies can effectively address the changing needs and expectations of their customers, ultimately driving business growth and loyalty.
# **Market Change Impact Analysis: Employees**
#
# **Section 1: Market Change Impacts**
#
# **Priority 1: Job Security Worries**
#
# * **Impact:** Market changes may lead to restructuring, downsizing, or changes in job roles, exacerbating employees' job security worries.
# * **Specific Impacts:**
# 	+ Uncertainty about job stability may lead to decreased morale, motivation, and productivity.
# 	+ Employees may be hesitant to take on new responsibilities or invest time in professional development.
# 	+ Turnover rates may increase as employees seek more stable opportunities.
#
# **Priority 2: Need for New Skills**
#
# * **Impact:** Market changes may require employees to acquire new skills to remain competitive and relevant.
# * **Specific Impacts:**
# 	+ Employees may feel overwhelmed by the need to constantly upskill or reskill.
# 	+ Lack of training or development opportunities may lead to feelings of stagnation and disengagement.
# 	+ Inability to adapt to new technologies or processes may result in decreased performance and job satisfaction.
#
# **Priority 3: Clear Direction**
#
# * **Impact:** Market changes may create uncertainty about the company's direction and strategy.
# * **Specific Impacts:**
# 	+ Employees may feel disconnected from the company's vision and goals.
# 	+ Lack of clear direction may lead to confusion, misalignment, and decreased collaboration among teams.
# 	+ Employees may struggle to prioritize tasks and make decisions without a clear understanding of the company's objectives.
#
# **Section 2: Recommended Actions**
#
# **Priority 1: Job Security Worries**
#
# * **Recommended Actions:**
# 	+ Communicate transparently about the company's strategy and plans for navigating market changes.
# 	+ Provide regular updates on the company's performance and progress.
# 	+ Offer support and resources for employees to develop new skills and adapt to changing job roles.
#
# **Priority 2: Need for New Skills**
#
# * **Recommended Actions:**
# 	+ Develop and implement training programs to help employees acquire new skills and stay competitive.
# 	+ Provide opportunities for cross-functional training and knowledge sharing.
# 	+ Encourage a culture of continuous learning and professional development.
#
# **Priority 3: Clear Direction**
#
# * **Recommended Actions:**
# 	+ Clearly communicate the company's vision, mission, and goals to all employees.
# 	+ Establish a regular feedback loop to ensure employees understand how their work contributes to the company's objectives.
# 	+ Foster an open-door policy, encouraging employees to ask questions and provide input on the company's direction.
#
# **Additional Recommendations:**
#
# * Conduct regular town hall meetings or focus groups to address employee concerns and provide a platform for feedback.
# * Develop an internal communication strategy to ensure that all employees receive timely and relevant information about market changes and the company's response.
# * Consider implementing employee engagement surveys to monitor morale and sentiment, and make data-driven decisions to address areas of concern.
# **Market Change Impact Analysis: Investors**
#
# **Section 1: Market Changes**
#
# * **Economic Downturn**: Global economic slowdown, reduced consumer spending, and decreased business investment
# * **Regulatory Shifts**: Stricter regulations, increased scrutiny, and changing reporting requirements
# * **Technological Disruptions**: Rapid advancements in technology, changing business models, and emerging competitors
#
# **Section 2: Impacts on Investors**
#
# **Priority 1: Growth Expectations**
#
# * **Impact**: Economic downturn and regulatory shifts may lead to reduced revenue growth, affecting investor returns
# * **Recommended Action**:
# 	+ Diversify revenue streams to mitigate risks
# 	+ Invest in cost-saving initiatives to maintain profitability
# 	+ Communicate proactively with investors about growth strategies and challenges
#
# **Priority 2: Cost Control**
#
# * **Impact**: Increased costs due to regulatory compliance, technological investments, and potential supply chain disruptions
# * **Recommended Action**:
# 	+ Implement cost-saving measures, such as process efficiencies and renegotiated contracts
# 	+ Invest in digital transformation to reduce costs and improve productivity
# 	+ Provide transparent cost breakdowns and regular updates to investors
#
# **Priority 3: Risk Concerns**
#
# * **Impact**: Regulatory shifts, technological disruptions, and economic downturn may increase risk exposure
# * **Recommended Action**:
# 	+ Conduct regular risk assessments and scenario planning to identify potential threats
# 	+ Develop and implement risk mitigation strategies, such as hedging and diversification
# 	+ Enhance transparency and disclosure around risk management practices
#
# **Additional Recommendations**
#
# * Engage in regular, open communication with investors to address concerns and provide updates on growth strategies, cost control measures, and risk management practices
# * Consider establishing an investor relations program to foster trust and transparency
# * Develop a comprehensive stakeholder engagement strategy to address the needs and concerns of all stakeholders, including investors
# **Market Change Impact Analysis: Suppliers**
#
# **Section 1: Capacity Constraints**
#
# * **Impact:** Suppliers may struggle to meet increasing demand, leading to delayed or incomplete deliveries, and potentially affecting the company's ability to fulfill customer orders on time.
# * **Recommended Actions:**
# 	1. **Prioritize:** Develop contingency plans with suppliers to ensure timely delivery of critical components.
# 	2. **Medium-term:** Collaborate with suppliers to invest in capacity expansion or explore alternative sourcing options.
# 	3. **Long-term:** Consider vertical integration or partnerships to secure supply chain stability.
#
# **Section 2: Price Pressures**
#
# * **Impact:** Suppliers may increase prices due to rising raw material costs, labor costs, or other factors, affecting the company's profit margins.
# * **Recommended Actions:**
# 	1. **Prioritize:** Negotiate with suppliers to lock in prices or explore cost-saving alternatives.
# 	2. **Medium-term:** Implement cost-reduction initiatives, such as process efficiencies or design optimizations, to offset price increases.
# 	3. **Long-term:** Develop strategic partnerships with suppliers to share risk and reward, and explore alternative sourcing options.
#
# **Section 3: Tech Transitions**
#
# * **Impact:** Suppliers may need to adapt to new technologies, such as Industry 4.0 or sustainable manufacturing, to remain competitive, which could lead to temporary disruptions or increased costs.
# * **Recommended Actions:**
# 	1. **Prioritize:** Collaborate with suppliers to develop a roadmap for tech transitions, ensuring minimal disruption to supply chain operations.
# 	2. **Medium-term:** Provide training and support to suppliers to facilitate the adoption of new technologies.
# 	3. **Long-term:** Consider investing in supplier development programs to drive innovation and competitiveness.
#
# **Overall Recommendations:**
#
# 1. **Regularly engage with suppliers** to monitor their capacity, pricing, and technology adoption.
# 2. **Develop a supplier scorecard** to track performance and identify areas for improvement.
# 3. **Foster collaborative relationships** with suppliers to drive mutual growth and innovation.
#
# By taking proactive steps to address these market changes, the company can mitigate potential risks and capitalize on opportunities to strengthen its supplier relationships and ensure a stable supply chain.

# %%
import re

def extract_xml(text: str, tag: str) -> str:
    """
    Extracts the content of the specified XML tag from the given text. Used for parsing structured responses 

    Args:
        text (str): The text containing the XML.
        tag (str): The XML tag to extract content from.

    Returns:
        str: The content of the specified XML tag, or an empty string if the tag is not found.
    """
    match = re.search(f'<{tag}>(.*?)</{tag}>', text, re.DOTALL)
    return match.group(1) if match else ""

# %%
def route(input: str, routes: Dict[str, str]) -> str:
    """Route input to specialized prompt using content classification."""
    # First determine appropriate route using LLM with chain-of-thought
    print(f"\nAvailable routes: {list(routes.keys())}")
    selector_prompt = f"""
    Analyze the input and select the most appropriate support team from these options: {list(routes.keys())}
    First explain your reasoning, then provide your selection in this XML format:

    <reasoning>
    Brief explanation of why this ticket should be routed to a specific team.
    Consider key terms, user intent, and urgency level.
    </reasoning>

    <selection>
    The chosen team name
    </selection>

    Input: {input}""".strip()
    
    route_response = llm_call(selector_prompt)
    print(route_response.strip())
    reasoning = extract_xml(route_response, 'reasoning')
    route_key = extract_xml(route_response, 'selection').strip().lower()
    
    print("Routing Analysis:")
    print(reasoning)
    print(f"\nSelected route: {route_key}")
    
    # Process input with selected specialized prompt
    selected_prompt = routes[route_key]
    return llm_call(f"{selected_prompt}\nInput: {input}")

# %%
# Example 3: Route workflow for customer support ticket handling
# Route support tickets to appropriate teams based on content analysis

support_routes = {
    "billing": """You are a billing support specialist. Follow these guidelines:
    1. Always start with "Billing Support Response:"
    2. First acknowledge the specific billing issue
    3. Explain any charges or discrepancies clearly
    4. List concrete next steps with timeline
    5. End with payment options if relevant
    
    Keep responses professional but friendly.
    
    Input: """,
    
    "technical": """You are a technical support engineer. Follow these guidelines:
    1. Always start with "Technical Support Response:"
    2. List exact steps to resolve the issue
    3. Include system requirements if relevant
    4. Provide workarounds for common problems
    5. End with escalation path if needed
    
    Use clear, numbered steps and technical details.
    
    Input: """,
    
    "account": """You are an account security specialist. Follow these guidelines:
    1. Always start with "Account Support Response:"
    2. Prioritize account security and verification
    3. Provide clear steps for account recovery/changes
    4. Include security tips and warnings
    5. Set clear expectations for resolution time
    
    Maintain a serious, security-focused tone.
    
    Input: """,
    
    "product": """You are a product specialist. Follow these guidelines:
    1. Always start with "Product Support Response:"
    2. Focus on feature education and best practices
    3. Include specific examples of usage
    4. Link to relevant documentation sections
    5. Suggest related features that might help
    
    Be educational and encouraging in tone.
    
    Input: """
}

# Test with different support tickets
tickets = [
    """Subject: Can't access my account
    Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error. 
    I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to 
    submit a report by end of day.
    - John""",
    
    """Subject: Unexpected charge on my card
    Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
    I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
    Thanks,
    Sarah""",
    
    """Subject: How to export data?
    Message: I need to export all my project data to Excel. I've looked through the docs but can't
    figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
    Best regards,
    Mike"""
]

print("Processing support tickets...\n")
for i, ticket in enumerate(tickets, 1):
    print(f"\nTicket {i}:")
    print("-" * 40)
    print(ticket)
    print("\nResponse:")
    print("-" * 40)
    response = route(ticket, support_routes)
    print(response)
# Out:
# Processing support tickets...
#
#
# Ticket 1:
# ----------------------------------------
# Subject: Can't access my account
#     Message: Hi, I've been trying to log in for the past hour but keep getting an 'invalid password' error.
#     I'm sure I'm using the right password. Can you help me regain access? This is urgent as I need to
#     submit a report by end of day.
#     - John
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Here is my analysis and selection:
#
# <reasoning>
# The user is experiencing an issue with logging into their account, specifically receiving an "invalid password" error despite being certain they are using the correct password. The user has explicitly stated that this is an urgent matter, as they need to submit a report by the end of the day. This suggests that the issue is time-sensitive and requires prompt attention. The key terms "can't access my account" and "invalid password" indicate an authentication-related problem, which is typically handled by the technical support team.
# </reasoning>
#
# <selection>
# technical
# </selection>
#
# I chose the technical support team because the issue is related to authentication and login, which falls under the technical domain. The user's urgent need to regain access to their account also suggests that a technical solution is required, rather than a billing or account-related issue.
# Routing Analysis:
#
# The user is experiencing an issue with logging into their account, specifically receiving an "invalid password" error despite being certain they are using the correct password. The user has explicitly stated that this is an urgent matter, as they need to submit a report by the end of the day. This suggests that the issue is time-sensitive and requires prompt attention. The key terms "can't access my account" and "invalid password" indicate an authentication-related problem, which is typically handled by the technical support team.
#
#
# Selected route: technical
# Technical Support Response:
#
# Dear John,
#
# Thank you for reaching out to our technical support team. I'm happy to assist you in resolving the issue with accessing your account.
#
# **Step 1: Password Reset**
#
# To rule out any password-related issues, let's try resetting your password. Please follow these steps:
#
# 1. Go to our website and click on the "Forgot Password" link.
# 2. Enter your username or email address associated with your account.
# 3. Click on the "Reset Password" button.
# 4. You will receive an email with a password reset link. Click on the link and follow the instructions to create a new password.
#
# **Step 2: Clear Browser Cache and Cookies**
#
# Sometimes, browser cache and cookies can cause issues with login functionality. Please try clearing your browser cache and cookies:
#
# 1. Close all instances of your web browser.
# 2. Open your browser and press the following keys simultaneously: Ctrl + Shift + Delete (Windows) or Command + Shift + Delete (Mac).
# 3. Select "Cookies and other site data" and "Cached images and files" and click "Clear data".
# 4. Restart your browser and try logging in again.
#
# **System Requirements:**
#
# Please ensure that your browser is up-to-date and meets our system requirements:
#
# * Browser: Google Chrome (latest version), Mozilla Firefox (latest version), or Microsoft Edge (latest version)
# * Operating System: Windows 10 or macOS High Sierra (or later)
#
# **Workaround:**
#
# If you're still experiencing issues, try using a different browser or device to log in to your account. This will help us determine if the issue is browser-specific or related to your device.
#
# **Escalation Path:**
#
# If you've followed the above steps and are still unable to access your account, please reply to this email with the following information:
#
# * The exact error message you're seeing
# * The browser and operating system you're using
# * Any additional details about the issue you're experiencing
#
# Our advanced technical support team will review your case and assist you further. We'll do our best to resolve the issue as quickly as possible to ensure you can submit your report on time.
#
# Thank you for your patience and cooperation.
#
# Best regards,
# [Your Name]
# Technical Support Engineer
#
# Ticket 2:
# ----------------------------------------
# Subject: Unexpected charge on my card
#     Message: Hello, I just noticed a charge of $49.99 on my credit card from your company, but I thought
#     I was on the $29.99 plan. Can you explain this charge and adjust it if it's a mistake?
#     Thanks,
#     Sarah
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Here is my analysis:
#
# <reasoning>
# The user is reporting an unexpected charge on their credit card, which suggests a billing-related issue. The user is also asking for an explanation and potential adjustment to the charge, which further supports the notion that this is a billing-related inquiry. The tone of the message is polite and inquiring, indicating a non-urgent issue.
# </reasoning>
#
# <selection>
# billing
# </selection>
#
# I chose the "billing" team because the user's concern is specifically about a charge on their credit card, which falls under the purview of the billing team. The user is seeking an explanation and potential correction, which are both tasks that the billing team is equipped to handle.
# Routing Analysis:
#
# The user is reporting an unexpected charge on their credit card, which suggests a billing-related issue. The user is also asking for an explanation and potential adjustment to the charge, which further supports the notion that this is a billing-related inquiry. The tone of the message is polite and inquiring, indicating a non-urgent issue.
#
#
# Selected route: billing
# Billing Support Response:
#
# Dear Sarah,
#
# Thank you for reaching out to us about the unexpected charge on your credit card. I apologize for any confusion or concern this may have caused. I'd be happy to help clarify the charge and assist with any necessary adjustments.
#
# After reviewing your account, I noticed that you were previously on our $29.99 plan, but you recently upgraded to our premium plan, which includes additional features and services, priced at $49.99. The charge you saw on your credit card is for the first month of this new plan.
#
# It's possible that you may not have received a notification about the plan change, and for that, I apologize. I'd like to offer you a one-time courtesy adjustment to revert back to your original $29.99 plan, if that's what you prefer.
#
# Here are the next steps:
#
# * I will process the adjustment within the next 24-48 hours, and you will receive an email confirmation once it's complete.
# * Your account will be updated to reflect the correct plan and pricing.
# * You will not be charged the premium rate going forward, unless you choose to upgrade again in the future.
#
# If you would like to proceed with the adjustment, please confirm by responding to this email. If you have any questions or would like to discuss further, I'm here to help.
#
# Payment options: If you'd like to make a payment towards your account, you can do so by logging into your online account or by calling our automated payment system at 1-800-XXX-XXXX. Alternatively, you can wait for your next scheduled payment date.
#
# Thank you for your patience and understanding. Please don't hesitate to reach out if you have any further questions or concerns.
#
# Best regards,
# [Your Name]
# Billing Support Specialist
#
# Ticket 3:
# ----------------------------------------
# Subject: How to export data?
#     Message: I need to export all my project data to Excel. I've looked through the docs but can't
#     figure out how to do a bulk export. Is this possible? If so, could you walk me through the steps?
#     Best regards,
#     Mike
#
# Response:
# ----------------------------------------
#
# Available routes: ['billing', 'technical', 'account', 'product']
# Here is my analysis:
#
# <reasoning>
# The user is asking about exporting data from their project to Excel, which suggests they need help with a specific feature or functionality of the product. The user has already looked through the documentation, implying that they need more personalized guidance. The tone of the message is polite and inquiring, with no sense of urgency or frustration. This suggests that the user is seeking assistance with a specific task rather than reporting a technical issue or billing problem.
# </reasoning>
#
# <selection>
# product
# </selection>
#
# I chose the "product" team because the user is asking about a specific feature of the product (exporting data to Excel) and needs guidance on how to use it. This type of inquiry is typically handled by a product support team, which is responsible for providing assistance with product features, functionality, and best practices.
# Routing Analysis:
#
# The user is asking about exporting data from their project to Excel, which suggests they need help with a specific feature or functionality of the product. The user has already looked through the documentation, implying that they need more personalized guidance. The tone of the message is polite and inquiring, with no sense of urgency or frustration. This suggests that the user is seeking assistance with a specific task rather than reporting a technical issue or billing problem.
#
#
# Selected route: product
# Product Support Response:
#
# Hi Mike,
#
# Thank you for reaching out to us! I'd be happy to help you with exporting your project data to Excel. Yes, bulk exporting is definitely possible, and I'd be delighted to guide you through the steps.
#
# To export your project data, follow these simple steps:
#
# 1. Navigate to the "Reports" tab in your project dashboard.
# 2. Click on the "Export" button located at the top-right corner of the page.
# 3. Select "Excel" as the export format from the dropdown menu.
# 4. Choose the specific data you want to export by selecting the relevant modules (e.g., tasks, issues, time entries, etc.).
# 5. Click "Export" to download the data in Excel format.
#
# You can also customize your export by applying filters, selecting specific date ranges, and choosing which columns to include in the export. For more information on customizing your exports, please refer to our documentation section on [Exporting Data](https://docs.ourproduct.com/en/articles/exporting-data).
#
# Additionally, you might find our [Data Export Templates](https://docs.ourproduct.com/en/articles/data-export-templates) feature helpful, which allows you to create reusable templates for frequent exports.
#
# If you have any further questions or need assistance with customizing your export, please don't hesitate to reach out. We're here to help!
#
# Best regards,
# [Your Name]
# Product Specialist
